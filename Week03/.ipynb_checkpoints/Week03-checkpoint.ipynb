# %% [markdown]
# # 표(table)
# * 데이터를 표의 형태로 표현하면 처리하기 편리함

# %% [markdown]
# ![%ED%91%9C.PNG](attachment:%ED%91%9C.PNG)

# %% [markdown]
# ## 데이터를 표로 표현하기

# %% [markdown]
# ![%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC%20%ED%91%9C%EB%A1%9C%ED%91%9C%ED%98%84%ED%95%98%EA%B8%B0.PNG](attachment:%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC%20%ED%91%9C%EB%A1%9C%ED%91%9C%ED%98%84%ED%95%98%EA%B8%B0.PNG)

# %% [markdown]
# ## 데이터들의 모임(DataSet)

# %% [markdown]
# ![%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%93%A4%EC%9D%98%20%EB%AA%A8%EC%9E%84_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B.PNG](attachment:%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%93%A4%EC%9D%98%20%EB%AA%A8%EC%9E%84_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B.PNG)

# %% [markdown]
# ## Pandas
# * **표를 다루는 파이썬 라이브러리**
# * Pandas API : <a>https://pandas.pydata.org/docs/reference/index.html</a>

# %% [markdown]
# ![%ED%8C%90%EB%8B%A4%EC%8A%A4.PNG](attachment:%ED%8C%90%EB%8B%A4%EC%8A%A4.PNG)

# %% [markdown]
# # 판다스의 자료구조 - 시리즈와 데이터프레임

# %% [markdown]
# ## 시리즈(Series)

# %% [markdown]
# ### Series 구조
# * 1차원 배열 형태

# %% [markdown]
# ![%EC%8B%9C%EB%A6%AC%EC%A6%88%EA%B5%AC%EC%A1%B0.PNG](attachment:%EC%8B%9C%EB%A6%AC%EC%A6%88%EA%B5%AC%EC%A1%B0.PNG)

# %% [markdown]
# ### Series의 생성
# * Python의 List나 Dictionary를 이용하여 생성
# * **pandas.Series(data, index, name)**

# %% [markdown]
# ### Series 만들기 - List이용
# * pandas.Series(리스트)

# %%
# 판다스 모듈 임포트 

import pandas as pd

# %%
# ['커피', '주스', '밀크티']를 data로 가지고
# 'aaa'라는 name을 가지는 시리즈 s1생성

s1=Series(data=[[]'커피','주스','밀크티'],name='aaa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33828/3254705500.py in <module>
#       2 # 'aaa'라는 name을 가지는 시리즈 s1생성
#       3
# ----> 4 s1=Series(data=['커피','주스','밀크티'],name='aaa')
#
# NameError: name 'Series' is not defined

# %%
# s1출력
# Out:
# 0     커피
# 1     주스
# 2    밀크티
# Name: aaa, dtype: object

# %% [markdown]
# ![%EC%8B%9C%EB%A6%AC%EC%A6%88%EB%A7%8C%EB%93%A4%EA%B8%B0.PNG](attachment:%EC%8B%9C%EB%A6%AC%EC%A6%88%EB%A7%8C%EB%93%A4%EA%B8%B0.PNG)

# %%
# s1 타입 확인
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Series - index, values

# %%
# s1의 인덱스 출력
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# s1의 데이터 출력
# Out:
# array(['커피', '주스', '밀크티'], dtype=object)

# %% [markdown]
# ### Series - 원하는 데이터 읽기

# %%
# '커피'선택하여 출력하기
# Out:
# '커피'

# %% [markdown]
# ### Series 만들기 - index 속성
# * pandas.Series(data, index)

# %%
# ['커피', '주스', '밀크티']를 data로 가지고
# ['coffee', 'juice', 'milktea']라는 index를 가지는 시리즈 s1생성

# %%
# s1 출력
# Out:
# coffee      커피
# juice       주스
# milktea    밀크티
# dtype: object

# %% [markdown]
# ![%EC%8B%9C%EB%A6%AC%EC%A6%88%EC%9D%B8%EB%8D%B1%EC%8A%A4%EA%B5%AC%EC%A1%B0.PNG](attachment:%EC%8B%9C%EB%A6%AC%EC%A6%88%EC%9D%B8%EB%8D%B1%EC%8A%A4%EA%B5%AC%EC%A1%B0.PNG)

# %%
# s1의 index 출력
# Out:
# Index(['coffee', 'juice', 'milktea'], dtype='object')

# %%
# s1의 values 출력
# Out:
# array(['커피', '주스', '밀크티'], dtype=object)

# %%
# '커피'선택하여 출력하기
# Out:
# '커피'

# %%
# '커피'선택하여 출력하기
# Out:
# '커피'

# %% [markdown]
# ### Series - 원소의 선택

# %% [markdown]
# ![%EC%8B%9C%EB%A6%AC%EC%A6%88-%EC%9B%90%EC%86%8C%EC%9D%98%EC%84%A0%ED%83%9D.PNG](attachment:%EC%8B%9C%EB%A6%AC%EC%A6%88-%EC%9B%90%EC%86%8C%EC%9D%98%EC%84%A0%ED%83%9D.PNG)

# %%
# 위 그림과 같은 시리즈 s1생성

# %%
# s1 출력
# Out:
# coffee      커피
# juice       주스
# milktea    밀크티
# dtype: object

# %%
# '밀크티' 출력
# Out:
# '밀크티'

# %%
# '밀크티' 출력
# Out:
# '밀크티'

# %%
# '밀크티' 타입 확인
# Out:
# str

# %%
# '밀크티' 타입 확인
# Out:
# str

# %%
# '커피', '주스' 선택하여 출력
# Out:
# coffee    커피
# juice     주스
# dtype: object

# %%
# '커피', '주스' 선택하여 출력
# Out:
# coffee    커피
# juice     주스
# dtype: object

# %%
# '커피', '주스' 선택하여 출력
# Out:
# coffee    커피
# juice     주스
# dtype: object

# %%
# '커피', '주스' 선택하여 출력
# Out:
# coffee    커피
# juice     주스
# dtype: object

# %%
# '커피', '주스' 선택하여 타입 확인
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Series 연산 - Series와 숫자 연산
# * Series객체 + 연산자(+, -, *, /) + 숫자
#    - 시리즈 개별 원소에 각각 숫자를 연산하고 결과를 시리즈 객체로 반환한다.

# %%
# data=[30, 45, 12], index=['국어', '영어', '수학']인 시리즈 객체 score1생성

# %%
# score1 확인
# Out:
# 국어    30
# 영어    45
# 수학    12
# dtype: int64

# %%
# score1 시리즈에 숫자 50을 더하여 score2에 대입

# %%
# score2확인
# Out:
# 국어    80
# 영어    95
# 수학    62
# dtype: int64

# %% [markdown]
# ### Series연산 - Series와 Series 연산
# * Series객체 + 연산자(+,-,*,/) + Seires객체
#   - index를 찾아 정렬한 후 같은 index의 data(value)들을 연산

# %% [markdown]
# ![%EC%8B%9C%EB%A6%AC%EC%A6%88%EC%97%B0%EC%82%B0.PNG](attachment:%EC%8B%9C%EB%A6%AC%EC%A6%88%EC%97%B0%EC%82%B0.PNG)

# %%
# 시리즈 객체 score1 만들기

# %%
# score1 확인
# Out:
# 국어    100
# 영어     80
# 수학     90
# dtype: int64

# %%
# 시리즈 객체 score2 만들기

# %%
# score2 확인
# Out:
# 수학    80
# 국어    90
# 영어    80
# dtype: int64

# %%
# 시리즈 객체 score1, score2를 더해 add에 대입하기

# %%
# add 확인
# Out:
# 국어    190
# 수학    170
# 영어    160
# dtype: int64

# %% [markdown]
# ## 데이터프레임
# * 행과 열로 만들어지는 2차원 배열 구조
# * 여러 개의 Series들이 모여서 하난의 DataFrame을 구성
# * DataFrame의 열은 각각 Series객체임
# * **행과 열을 나타내기 위해 두 가지 종류의 index를 사용**
#     - **행인덱스**
#     - **컬럼명**
# * 열은 공통의 속성을 갖는 일련의 데이터를 나타냄
# * 행은 개별 관측대상(observation)에 대한 다양한 속성 데이터들의 모음인 Record임

# %% [markdown]
# ### DataFrame의 구조

# %% [markdown]
# ![%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EA%B5%AC%EC%A1%B0.PNG](attachment:%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EA%B5%AC%EC%A1%B0.PNG)

# %% [markdown]
# ### DataFrame의 생성
# * Python의 List나 Dictionary를 이용하여 생성
# * Series로 생성
# * **pandas.DataFrame(data, index, columns)**

# %% [markdown]
# ### DataFrame 만들기 - Dictionary이용
# * 딕셔너리의 키 -> 컬럼명
# * 딕셔너리의 값 -> 컬럼데이터

# %%
# 첫번째 컬럼 -> 이름: '제품명', 데이터: '커피','주스','밀크티'
# 두번째 컬럼 -> 이름: '가격', 데이터: 5000, 6000, 6500
# 세번째 컬럼 -> 이름: '판매량', 데이터:60, 45, 30 인 데이터프레임 객체 df만들기

# %%
# df 확인
# Out:
#    제품명    가격  판매량
# 0   커피  5000   60
# 1   주스  6000   45
# 2  밀크티  6500   30

# %% [markdown]
# ![%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EB%A7%8C%EB%93%A4%EA%B8%B0_%EB%94%95%EC%85%94%EB%84%88%EB%A6%AC%EC%9D%B4%EC%9A%A9.PNG](attachment:%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%94%84%EB%A0%88%EC%9E%84%EB%A7%8C%EB%93%A4%EA%B8%B0_%EB%94%95%EC%85%94%EB%84%88%EB%A6%AC%EC%9D%B4%EC%9A%A9.PNG)

# %%
# df의 타입 확인
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### DataFrame - index, columns, values, shape, dtypes, info()

# %%
# 데이터프레임의 index?
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# 데이터프레임의 columns?
# Out:
# Index(['제품명', '가격', '판매량'], dtype='object')

# %%
# 데이터프레임의 데이터?
# Out:
# array([['커피', 5000, 60],
#        ['주스', 6000, 45],
#        ['밀크티', 6500, 30]], dtype=object)

# %%
# 데이터프레임이 몇행 몇열?
# Out:
# (3, 3)

# %%
# 데이터프레임이 몇행?
# Out:
# 3

# %%
# 데이터프레임이 몇열?
# Out:
# 3

# %%
# 데이터프레임의 각 열은 무슨타입?
# Out:
# 제품명    object
# 가격      int64
# 판매량     int64
# dtype: object

# %%
# df는 무슨 타입?
# Out:
# pandas.core.frame.DataFrame

# %%
# 데이터프레임의 각 열의 요약정보
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     3 non-null      object
#  1   가격      3 non-null      int64
#  2   판매량     3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes

# %% [markdown]
# ### DataFrame - index, columns  변경하기
# * 행인덱스 변경: **DataFrame객체.index = [새인덱스리스트]**
# * 열 이름 변경: **DataFrame객체.columns = [새컬럼명리스트]**
# * 행인덱스 변경: **DataFrame객체.rename(index={기존인덱스명:새인덱스명,...})**
# * 열 이름 변경: **DataFrame객체.rename(columns={기존컬럼명:새컬럼명,...})**
#
#
# * 특정 열을 행 인덱스로 설정 : **DataFrame객체.set_index(['열이름'] 또는 '열이름')**
# * 행인덱스 초기화 : **DataFrame객체.reset_index()**
#     * 행 인덱스를 정수형 위치 인덱스로 초기화한다. 이때 기존 행 인덱스는 열로 이동한다.

# %%
# df 확인
# Out:
#    제품명    가격  판매량
# 0   커피  5000   60
# 1   주스  6000   45
# 2  밀크티  6500   30

# %%
# df의 인덱스를 '음료1', '음료2', '음료3'으로 바꾸기
# Out:
#      제품명    가격  판매량
# 음료1   커피  5000   60
# 음료2   주스  6000   45
# 음료3  밀크티  6500   30

# %%
# df의 컬럼명을 '음료명', '판매가격', '판매수량'으로 바꾸기
# Out:
#      음료명  판매가격  판매수량
# 음료1   커피  5000    60
# 음료2   주스  6000    45
# 음료3  밀크티  6500    30

# %%
# df의 '음료명'컬럼명을 '제품명'으로 바꾸고, '음료1'인덱스를 'coffee'로 바꾸기
# Out:
#         제품명  판매가격  판매수량
# coffee   커피  5000    60
# 음료2      주스  6000    45
# 음료3     밀크티  6500    30

# %%
# df확인 , 변경 안됨
# Out:
#      음료명  판매가격  판매수량
# 음료1   커피  5000    60
# 음료2   주스  6000    45
# 음료3  밀크티  6500    30

# %%
# inplace=True

# %%
# df확인, 변경됨
# Out:
#         제품명  판매가격  판매수량
# coffee   커피  5000    60
# 음료2      주스  6000    45
# 음료3     밀크티  6500    30

# %%
# '제품명' 컬럼을 인덱스로 설정한다.
# Out:
#      판매가격  판매수량
# 제품명
# 커피   5000    60
# 주스   6000    45
# 밀크티  6500    30

# %%
# df확인, 변경안됨
# Out:
#         제품명  판매가격  판매수량
# coffee   커피  5000    60
# 음료2      주스  6000    45
# 음료3     밀크티  6500    30

# %%
# df.set_index('제품명', inplace=True)와 동일한 효과를 내기위해
# df.set_index()한 결과를 df변수에 대입

# %%
# df확인
# Out:
#      판매가격  판매수량
# 제품명
# 커피   5000    60
# 주스   6000    45
# 밀크티  6500    30

# %%
# df의 인덱스를 정수형 위치 인덱스로 초기화한다.
# 결과를 df변수에 대입

# %% [markdown]
# ### DataFrame - 정렬 : 행인덱스를 기준으로
# * **DataFrame객체.sort_index()** : 인덱스를 기준으로 오름차순 정렬
#     - ascending=False: 내림차순정렬

# %%
# df 확인
# Out:
#    제품명  판매가격  판매수량
# 0   커피  5000    60
# 1   주스  6000    45
# 2  밀크티  6500    30

# %%
# df의 인덱스를 [2, 3, 1]로 변경하기

# %%
# df확인
# Out:
#    제품명  판매가격  판매수량
# 2   커피  5000    60
# 3   주스  6000    45
# 1  밀크티  6500    30

# %%
# 인덱스기준으로 오름차순으로 정렬
# Out:
#    제품명  판매가격  판매수량
# 1  밀크티  6500    30
# 2   커피  5000    60
# 3   주스  6000    45

# %%
# 인덱스 기준으로 내림차순으로 정렬
# Out:
#    제품명  판매가격  판매수량
# 3   주스  6000    45
# 2   커피  5000    60
# 1  밀크티  6500    30

# %%
# df확인, 변경되지 않았음

df
# Out:
#    제품명  판매가격  판매수량
# 2   커피  5000    60
# 3   주스  6000    45
# 1  밀크티  6500    30

# %%
# df의 인덱스를 'b', 'a', 'c'로 변경
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %%
# 인덱스기준으로 오름차순으로 정렬
# Out:
#    제품명  판매가격  판매수량
# a   주스  6000    45
# b   커피  5000    60
# c  밀크티  6500    30

# %%
# 인덱스기준으로 내림차순으로 정렬
# Out:
#    제품명  판매가격  판매수량
# c  밀크티  6500    30
# b   커피  5000    60
# a   주스  6000    45

# %%
# df확인, 변경되지 않았음
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %% [markdown]
# ### DataFrame - 정렬 : 특정열의 값을 기준으로
# * **DataFrame객체.sort_values(by='정렬기준컬럼명')** : by컬럼을 기준으로 오름차순 정렬
#     - ascending=False: 내림차순정렬

# %%
# df확인
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %%
# '제품명'을 기준으로 오름차순 정렬
# Out:
#    제품명  판매가격  판매수량
# c  밀크티  6500    30
# a   주스  6000    45
# b   커피  5000    60

# %%
# df확인, 변경되지 않았음
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %%
# '제품명'을 기준으로 내림차순 정렬
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %%
# '판매가격'컬럼을 선택(시리즈객체)하여 정렬
# Out:
# b    5000
# a    6000
# c    6500
# Name: 판매가격, dtype: int64

# %%
# df확인
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   주스  6000    45
# c  밀크티  6500    30

# %%
# 주스를 커피로 변경

df.iloc[1, 0]='커피'
df
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   커피  6000    45
# c  밀크티  6500    30

# %%
# '제품명'과 '판매수량'을 기준으로 오름차순 정렬
# Out:
#    제품명  판매가격  판매수량
# c  밀크티  6500    30
# a   커피  6000    45
# b   커피  5000    60

# %%
# '제품명'과 '판매수량'을 기준으로 내림차순 정렬
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   커피  6000    45
# c  밀크티  6500    30

# %%
# '제품명'은 오름차순, '판매수량'은 내림차순으로 정렬
# Out:
#    제품명  판매가격  판매수량
# c  밀크티  6500    30
# b   커피  5000    60
# a   커피  6000    45

# %% [markdown]
# ### DataFrame 연산 - DataFrame 과 숫자연산
# * DataFrame객체 + 연산자(+, -, *, /) + 숫자
# 데이터프레임 개별 원소에 각각 숫자를 연산하고 결과를 데이터프레임객체로 반환한다.

# %%
# 첫번째 컬럼명 -> '국어', 데이터: 80, 63, 77
# 두번째 컬럼명 -> '영어', 데이터: 90, 20, 55 인 데이터프레임 객체 df1 만들기
# Out:
#    국어  영어
# 0  80  90
# 1  63  20
# 2  77  55

# %%
# df1에 숫자 10 더하기
# Out:
#    국어   영어
# 0  90  100
# 1  73   30
# 2  87   65

# %% [markdown]
# ###  DataFrame 연산 - DataFrame과 DataFrame 연산
# * DataFrame객체 + 연산자(+,-,*,/)  + DataFrame객체
# index를 찾아 정렬한 후 같은 index의 data(value)들을 연산

# %%
# df1 확인
# Out:
#    국어  영어
# 0  80  90
# 1  63  20
# 2  77  55

# %%
# numpy 임포트

# %%
# 첫번째 컬럼명 -> '국어', 데이터: 70, 83, 47
# 두번째 컬럼명 -> '영어', 데이터: NaN, 90, 78 
# 세번째 컬럼명 -> '수학', 데이터: 90, 20, NaN 인 데이터프레임 객체 df2 만들기
# Out:
#    국어    영어    수학
# 0  70   NaN  90.0
# 1  83  90.0  20.0
# 2  47  78.0   NaN

# %%
# df1 + df2
# Out:
#     국어  수학     영어
# 0  150 NaN    NaN
# 1  146 NaN  110.0
# 2  124 NaN  133.0

# %% [markdown]
# # 데이터 입출력

# %% [markdown]
# * 판다스는 다양한 형태의 외부 파일을 읽어와서 데이터프레임으로 변환하는 함수를 제공한다.
# * 어떤 파일이든 판다스 객체인 데이터프레임으로 변환되고 나면 판다스의 모든 함수와 기능을 자유롭게 사용할 수 있다.
# * 반대로 데이터프레임을 다양한 유형의 파일로 저장할 수도 있다.

# %% [markdown]
# * csv파일로 저장하기
#     * **DataFrame객체.to_csv('파일이름(경로)')**
# * csv파일로 읽어오기
#     * **pandas.read_csv('파일이름(경로)', index_col=인덱스컬럼번호, header=헤더로 지정할 행번호, sep='구분자')**

# %%
# df 확인
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   커피  6000    45
# c  밀크티  6500    30

# %%
# df를 ./data/음료판매기록.csv 파일로 저장

# %%
# ./data/음료판매기록.csv파일 읽어 데이터프레임 객체를 df1에대입

# %%
# df1 확인하기
# Out:
#   Unnamed: 0  제품명  판매가격  판매수량
# 0          b   커피  5000    60
# 1          a   커피  6000    45
# 2          c  밀크티  6500    30

# %%
# index_col = 0 옵션주고 읽어오기

# %%
# df1 확인
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   커피  6000    45
# c  밀크티  6500    30

# %%
# header=None 옵션주고 읽어오기

# %%
# df1 확인하기
# Out:
#      0    1     2     3
# 0  NaN  제품명  판매가격  판매수량
# 1    b   커피  5000    60
# 2    a   커피  6000    45
# 3    c  밀크티  6500    30

# %%
# header = 0, index_col=0 , sep=',' 옵션주고 읽어오기

# %%
# df1 확인하기
# Out:
#    제품명  판매가격  판매수량
# b   커피  5000    60
# a   커피  6000    45
# c  밀크티  6500    30
